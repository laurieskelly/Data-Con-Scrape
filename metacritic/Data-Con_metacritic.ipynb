# %% [markdown]
# ## Metacritic:
# **This is an example of a work in progress. **
#
# Scraping metacritic, like many webscraping projects, involves two steps.
#
# 1. Parse a main page full of links to other things (like the stories on the front page of a news site, the categories on a retail website), sometimes iteratively, until you have a list of links to your "units" of interst
#   - sometimes these are called "producers" because they produce urls of items you want to gather information about
# 2. Parse each atomic unit of interest to get its detailed information.
#
# I often use ipython notebooks to hack through the trial-and-error process of getting my scrapers to work. I start with simple commands or chunks of code (mini-scripts), and debug as I go.
#
# As I go, I collect these into functions.
#
# When I've reached a good stopping point, I copy these functions into a python file, perhaps creating classes, and then I start a new notebook for the next step, import the stuff I made in the first step, and repeat the process on the second (probably atomic) level.
#
# ###In this notebook,
# you see the products of the hacking and function-izing that I did to get movies from a page on metacritic.
#
# On this pass, I get the links to the main pages for each movie, and "while I'm here", I get the information available from the list. I'll add more information about each movie in future steps.
#
# ### The functions from this notebook
# are collected in the file `metacritic_scraper.py`. You'll see in the next notebook, Data-Con-metacritic2.ipynb, how I import that file and use it to continue hacking on metacritic movie ratings and information.
#
# ### The final project I included in this repo
# is a scraper that collects information about links on datatau.com. It is a (nearly) completed product (nearly) ready to deploy as a cron task so I can see over time how (and which) links gain (or don't) gain votes and ranking on datatau.
#
#
# ##To make this work:
# "run" each function cell to get it into your namespace, then try it out with the cells at the bottom of the notebook.

# %%
import requests
from bs4 import BeautifulSoup
import bs4.element

def connection(url):
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
    r = requests.get(url,headers=headers)
    soup = BeautifulSoup(r.text)
    return soup

# %%
def scrape_metacritic_list_page(soup,movie_list=[]):
    for release_type,mlist in get_modules(soup).items():
        for movie in mlist:
            try:
                m = parse_movie_li(movie)
            except:
                bad.append(movie)
                continue
            m['release_type']=release_type
            movie_list.append(m)
    return movie_list

def just_tags(thinglist):
    tags = [t for t in thinglist if isinstance(t,bs4.element.Tag)]
    return tags
    
def get_modules(soup):
    modules = soup.find_all(class_='product_condensed')
    module_dict = {}
    for mod in modules: 
        label = mod.find(class_='release_type_label').text
        movie_lis = just_tags(mod.find('ol').contents)
        module_dict[label]=movie_lis
    return module_dict

# %%
from dateutil import parser

def parse_movie_li(li):
    title_div = li.find(class_='product_title')
    
    movie = {
        'title':title_div.text.strip(),
        'rel_url':title_div.find('a')['href'],
        'metascore_w':get_metascore_w(li.find(class_='metascore_w')),
        'release_date': get_release_date(li.find(class_='release_date').find(class_='data'))
    }
    #print movie,'\n'
    return movie
    
def get_metascore_w(div):
    try:
        score = div.text
    except:
        print 'no text in metascore div'
        return None
    try: 
        score = int(score)
    except: 
        pass
    return score
    
    
def get_release_date(div):
    try: 
        datestr = div.text
    except:
        return None
    try: 
        date = parser.parse(datestr)
    except:
        return datestr
    return date

# %% [markdown]
# ##To try it out:
#
# I define my starting url, and then request the html and make a soup object from the response.

# %%
url = 'http://www.metacritic.com/browse/movies/release-date/theaters/date'
soup = connection(url)

# %% [markdown]
# ##Then,
# you can skip all of the middlemen and go from soup to a dictionary of tasty data using this function

# %%
movie_list = scrape_metacritic_list_page(soup)
movie_list
# Out:
# [{'metascore_w': 59,
#   'rel_url': '/movie/dolphin-tale-2',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Dolphin Tale 2'},
#  {'metascore_w': 24,
#   'rel_url': '/movie/no-good-deed-2014',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'No Good Deed'},
#  {'metascore_w': 69,
#   'rel_url': '/movie/animal-rescue',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The Drop'},
#  {'metascore_w': 25,
#   'rel_url': '/movie/the-identical',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The Identical'},
#  {'metascore_w': 38,
#   'rel_url': '/movie/as-above-so-below',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'As Above, So Below'},
#  {'metascore_w': 38,
#   'rel_url': '/movie/the-november-man',
#   'release_date': datetime.datetime(2014, 8, 27, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The November Man'},
#  {'metascore_w': 47,
#   'rel_url': '/movie/if-i-stay',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'If I Stay'},
#  {'metascore_w': 45,
#   'rel_url': '/movie/frank-millers-sin-city-a-dame-to-kill-for',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Sin City: A Dame To Kill For'},
#  {'metascore_w': 41,
#   'rel_url': '/movie/when-the-game-stands-tall',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'When the Game Stands Tall'},
#  {'metascore_w': 35,
#   'rel_url': '/movie/the-expendables-3',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The Expendables 3'},
#  {'metascore_w': 47,
#   'rel_url': '/movie/the-giver',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The Giver'},
#  {'metascore_w': 30,
#   'rel_url': '/movie/lets-be-cops',
#   'release_date': datetime.datetime(2014, 8, 13, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u"Let's Be Cops"},
#  {'metascore_w': 44,
#   'rel_url': '/movie/into-the-storm',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Into the Storm'},
#  {'metascore_w': 45,
#   'rel_url': '/movie/step-up-all-in',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Step Up: All In'},
#  {'metascore_w': 31,
#   'rel_url': '/movie/teenage-mutant-ninja-turtles',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Teenage Mutant Ninja Turtles'},
#  {'metascore_w': 55,
#   'rel_url': '/movie/the-hundred-foot-journey',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The Hundred-Foot Journey'},
#  {'metascore_w': 59,
#   'rel_url': '/movie/the-f-word',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'What If'},
#  {'metascore_w': 71,
#   'rel_url': '/movie/get-on-up',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Get On Up'},
#  {'metascore_w': 76,
#   'rel_url': '/movie/guardians-of-the-galaxy',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Guardians of the Galaxy'},
#  {'metascore_w': 73,
#   'rel_url': '/movie/a-most-wanted-man',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'A Most Wanted Man'},
#  {'metascore_w': 38,
#   'rel_url': '/movie/and-so-it-goes',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'And So It Goes'},
#  {'metascore_w': 47,
#   'rel_url': '/movie/hercules',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Hercules'},
#  {'metascore_w': 61,
#   'rel_url': '/movie/lucy',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Lucy'},
#  {'metascore_w': 54,
#   'rel_url': '/movie/magic-in-the-moonlight',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Magic in the Moonlight'},
#  {'metascore_w': 11,
#   'rel_url': '/movie/persecuted',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Persecuted'},
#  {'metascore_w': 48,
#   'rel_url': '/movie/planes-fire-rescue',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Planes: Fire & Rescue'},
#  {'metascore_w': 36,
#   'rel_url': '/movie/sex-tape',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Sex Tape'},
#  {'metascore_w': 49,
#   'rel_url': '/movie/the-purge-anarchy',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'The Purge: Anarchy'},
#  {'metascore_w': 43,
#   'rel_url': '/movie/wish-i-was-here',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Wide releases now in theaters',
#   'title': u'Wish I Was Here'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/108-stitches',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'108 Stitches'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/altina',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Altina'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/alumbrones',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Alumbrones'},
#  {'metascore_w': 39,
#   'rel_url': '/movie/archaeology-of-a-woman',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Archaeology of a Woman'},
#  {'metascore_w': 47,
#   'rel_url': '/movie/at-the-devils-door',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u"At the Devil's Door"},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/atlas-shrugged-iii-who-is-john-galt',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Atlas Shrugged III: Who Is John Galt?'},
#  {'metascore_w': 39,
#   'rel_url': '/movie/believe',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Believe'},
#  {'metascore_w': 71,
#   'rel_url': '/movie/bird-people',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Bird People'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/faith-connections',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Faith Connections'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/finding-fanny',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Finding Fanny'},
#  {'metascore_w': 68,
#   'rel_url': '/movie/honeymoon',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Honeymoon'},
#  {'metascore_w': 54,
#   'rel_url': '/movie/i-am-eleven',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'I Am Eleven'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/living-is-easy-with-eyes-closed',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Living Is Easy with Eyes Closed'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/pump',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Pump'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/smiling-through-the-apocalypse',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Smiling Through the Apocalypse: Esquire in the 60s'},
#  {'metascore_w': 84,
#   'rel_url': '/movie/stray-dogs',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Stray Dogs'},
#  {'metascore_w': 18,
#   'rel_url': '/movie/swearnet-the-movie',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Swearnet: The Movie'},
#  {'metascore_w': 57,
#   'rel_url': '/movie/take-me-to-the-river',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Take Me to the River'},
#  {'metascore_w': 55,
#   'rel_url': '/movie/the-disappearance-of-eleanor-rigby-them',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Disappearance of Eleanor Rigby: Them'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/the-frontier',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Frontier'},
#  {'metascore_w': 65,
#   'rel_url': '/movie/the-green-prince-2014',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Green Prince'},
#  {'metascore_w': 27,
#   'rel_url': '/movie/the-man-on-her-mind',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Man on Her Mind'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/pirates',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Pirates'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/the-quitter',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Quitter'},
#  {'metascore_w': 76,
#   'rel_url': '/movie/the-skeleton-twins',
#   'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Skeleton Twins'},
#  {'metascore_w': 76,
#   'rel_url': '/movie/born-to-fly',
#   'release_date': datetime.datetime(2014, 9, 10, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Born to Fly'},
#  {'metascore_w': 54,
#   'rel_url': '/movie/my-old-lady',
#   'release_date': datetime.datetime(2014, 9, 10, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'My Old Lady'},
#  {'metascore_w': 16,
#   'rel_url': '/movie/but-always',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'But Always'},
#  {'metascore_w': 50,
#   'rel_url': '/movie/falcon-rising',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Falcon Rising'},
#  {'metascore_w': 58,
#   'rel_url': '/movie/frontera',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Frontera'},
#  {'metascore_w': 58,
#   'rel_url': '/movie/god-help-the-girl',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'God Help the Girl'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/gringo-trails',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Gringo Trails'},
#  {'metascore_w': 26,
#   'rel_url': '/movie/innocence-2014',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Innocence'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/jason-nash-is-married',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Jason Nash Is Married'},
#  {'metascore_w': 64,
#   'rel_url': '/movie/kelly-cal',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Kelly & Cal'},
#  {'metascore_w': 85,
#   'rel_url': '/movie/last-days-in-vietnam',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Last Days in Vietnam'},
#  {'metascore_w': 83,
#   'rel_url': '/movie/levitated-mass',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Levitated Mass'},
#  {'metascore_w': 63,
#   'rel_url': '/movie/memphis',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Memphis'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/naked-opera',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Naked Opera'},
#  {'metascore_w': 68,
#   'rel_url': '/movie/no-no-a-dockumentary',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'No No: A Dockumentary'},
#  {'metascore_w': 77,
#   'rel_url': '/movie/once-upon-a-time-veronica',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Once Upon a Time Ver\xf4nica'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/pay-2-play',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Pay 2 Play: Democracy\u2019s High Stakes'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/the-green-inferno',
#   'release_date': u'TBD',
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Green Inferno'},
#  {'metascore_w': 34,
#   'rel_url': '/movie/the-longest-week',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Longest Week'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/the-remaining',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Remaining'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/the-rule',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Rule'},
#  {'metascore_w': 47,
#   'rel_url': '/movie/thunder-and-the-house-of-magic',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Thunder and the House of Magic'},
#  {'metascore_w': 76,
#   'rel_url': '/movie/wetlands',
#   'release_date': datetime.datetime(2014, 9, 5, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Wetlands'},
#  {'metascore_w': 78,
#   'rel_url': '/movie/rocks-in-my-pockets',
#   'release_date': datetime.datetime(2014, 9, 3, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Rocks in My Pockets'},
#  {'metascore_w': 64,
#   'rel_url': '/movie/canopy',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Canopy'},
#  {'metascore_w': 45,
#   'rel_url': '/movie/cantinflas',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Cantinflas'},
#  {'metascore_w': 49,
#   'rel_url': '/movie/jamie-marks-is-dead',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Jamie Marks Is Dead'},
#  {'metascore_w': 55,
#   'rel_url': '/movie/kundo-age-of-the-rampant',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Kundo: Age of the Rampant'},
#  {'metascore_w': 40,
#   'rel_url': '/movie/last-weekend',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Last Weekend'},
#  {'metascore_w': 60,
#   'rel_url': '/movie/life-of-crime',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Life of Crime'},
#  {'metascore_w': 66,
#   'rel_url': '/movie/patema-inverted',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Patema Inverted'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/raja-natwarlal',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Raja Natwarlal'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/road-to-ninja-naruto-the-movie',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Road to Ninja: Naruto the Movie'},
#  {'metascore_w': 42,
#   'rel_url': '/movie/second-opinion-laetrile-at-sloan-kettering',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Second Opinion: Laetrile at Sloan-Kettering'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/shadows-from-my-past',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Shadows from My Past'},
#  {'metascore_w': 46,
#   'rel_url': '/movie/the-calling',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Calling'},
#  {'metascore_w': 63,
#   'rel_url': '/movie/the-congress',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Congress'},
#  {'metascore_w': 40,
#   'rel_url': '/movie/the-damned-2014',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Damned'},
#  {'metascore_w': 46,
#   'rel_url': '/movie/the-last-of-robin-hood',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Last of Robin Hood'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/el-cuarto-desnudo',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Naked Room'},
#  {'metascore_w': 55,
#   'rel_url': '/movie/the-notebook-2014',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Notebook'},
#  {'metascore_w': 53,
#   'rel_url': '/movie/the-strange-color-of-your-bodys-tears',
#   'release_date': datetime.datetime(2014, 8, 29, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u"The Strange Color of Your Body's Tears"},
#  {'metascore_w': 82,
#   'rel_url': '/movie/starred-up',
#   'release_date': datetime.datetime(2014, 8, 27, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Starred Up'},
#  {'metascore_w': 61,
#   'rel_url': '/movie/through-a-lens-darkly',
#   'release_date': datetime.datetime(2014, 8, 27, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Through a Lens Darkly: Black Photographers And The Emergence Of A People'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/another-me',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Another Me'},
#  {'metascore_w': 37,
#   'rel_url': '/movie/are-you-here',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Are You Here'},
#  {'metascore_w': 26,
#   'rel_url': '/movie/cam2cam',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Cam2Cam'},
#  {'metascore_w': 63,
#   'rel_url': '/movie/k2-siren-of-the-himalayas',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'K2: Siren of the Himalayas'},
#  {'metascore_w': 48,
#   'rel_url': '/movie/kabbalah-me',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Kabbalah Me'},
#  {'metascore_w': 67,
#   'rel_url': '/movie/kink',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Kink'},
#  {'metascore_w': 84,
#   'rel_url': '/movie/love-is-strange',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Love Is Strange'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/mardaani',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Mardaani'},
#  {'metascore_w': 56,
#   'rel_url': '/movie/may-in-the-summer',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'May in the Summer'},
#  {'metascore_w': 65,
#   'rel_url': '/movie/metro-manila',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Metro Manila'},
#  {'metascore_w': 59,
#   'rel_url': '/movie/salvo',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Salvo'},
#  {'metascore_w': 65,
#   'rel_url': '/movie/the-one-i-love',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The One I Love'},
#  {'metascore_w': 17,
#   'rel_url': '/movie/the-prince',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Prince'},
#  {'metascore_w': 67,
#   'rel_url': '/movie/to-be-takei',
#   'release_date': datetime.datetime(2014, 8, 22, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'To Be Takei'},
#  {'metascore_w': 77,
#   'rel_url': '/movie/expedition-to-the-end-of-the-world',
#   'release_date': datetime.datetime(2014, 8, 20, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Expedition to the End of the World'},
#  {'metascore_w': 49,
#   'rel_url': '/movie/winter-in-the-blood',
#   'release_date': datetime.datetime(2014, 8, 20, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Winter in the Blood'},
#  {'metascore_w': 54,
#   'rel_url': '/movie/a-will-for-the-woods',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'A Will for the Woods'},
#  {'metascore_w': 80,
#   'rel_url': '/movie/abuse-of-weakness',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Abuse of Weakness'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/captivated-the-trials-of-pamela-smart',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Captivated: The Trials of Pamela Smart'},
#  {'metascore_w': 71,
#   'rel_url': '/movie/cheatin',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u"Cheatin'"},
#  {'metascore_w': 45,
#   'rel_url': '/movie/coldwater',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Coldwater'},
#  {'metascore_w': 66,
#   'rel_url': '/movie/dinosaur-13',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Dinosaur 13'},
#  {'metascore_w': 47,
#   'rel_url': '/movie/fort-mccoy',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Fort McCoy'},
#  {'metascore_w': 41,
#   'rel_url': '/movie/found',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Found'},
#  {'metascore_w': 75,
#   'rel_url': '/movie/frank',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Frank'},
#  {'metascore_w': 33,
#   'rel_url': '/movie/i-am-happiness-on-earth',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'I Am Happiness on Earth'},
#  {'metascore_w': 30,
#   'rel_url': '/movie/jake-squared',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Jake Squared'},
#  {'metascore_w': 66,
#   'rel_url': '/movie/jealousy',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Jealousy'},
#  {'metascore_w': 91,
#   'rel_url': '/movie/level-five',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Level Five'},
#  {'metascore_w': 50,
#   'rel_url': '/movie/life-after-beth',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Life After Beth'},
#  {'metascore_w': 77,
#   'rel_url': '/movie/mission-blue',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Mission Blue'},
#  {'metascore_w': 67,
#   'rel_url': '/movie/mr-x',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Mr. X'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/nightlights',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'NightLights'},
#  {'metascore_w': 49,
#   'rel_url': '/movie/ragnarok',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Ragnarok'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/red-hollywood',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Red Hollywood'},
#  {'metascore_w': 7,
#   'rel_url': '/movie/septic-man',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Septic Man'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/the-admiral-roaring-currents',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Admiral: Roaring Currents'},
#  {'metascore_w': 75,
#   'rel_url': '/movie/the-trip-to-italy',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Trip to Italy'},
#  {'metascore_w': 20,
#   'rel_url': '/movie/the-word',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Word'},
#  {'metascore_w': 65,
#   'rel_url': '/movie/somos-mari-pepa',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'We Are Mari Pepa'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/weaving-the-past-journey-of-discovery',
#   'release_date': datetime.datetime(2014, 8, 15, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Weaving the Past: Journey of Discovery'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/37-a-final-promise',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'37: A Final Promise'},
#  {'metascore_w': 45,
#   'rel_url': '/movie/about-alex',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'About Alex'},
#  {'metascore_w': 25,
#   'rel_url': '/movie/after',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'After'},
#  {'metascore_w': 58,
#   'rel_url': '/movie/deepsea-challenge-3d',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Deepsea Challenge 3D'},
#  {'metascore_w': 77,
#   'rel_url': '/movie/fifi-howls-from-happiness',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Fifi Howls from Happiness'},
#  {'metascore_w': 76,
#   'rel_url': '/movie/the-dog',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Dog'},
#  {'metascore_w': 39,
#   'rel_url': '/movie/the-maids-room',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u"The Maid's Room"},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/us-and-the-game-industry',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Us and the Game Industry'},
#  {'metascore_w': 86,
#   'rel_url': '/movie/what-now-remind-me',
#   'release_date': datetime.datetime(2014, 8, 8, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'What Now? Remind Me'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/a-fuller-life',
#   'release_date': datetime.datetime(2014, 8, 6, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'A Fuller Life'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/dragon-ball-z-battle-of-gods',
#   'release_date': datetime.datetime(2014, 8, 6, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Dragon Ball Z: Battle of Gods'},
#  {'metascore_w': 67,
#   'rel_url': '/movie/web-junkie',
#   'release_date': datetime.datetime(2014, 8, 6, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Web Junkie'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/slugterra-return-of-the-elementals',
#   'release_date': datetime.datetime(2014, 8, 2, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Slugterra: Return of the Elementals'},
#  {'metascore_w': 48,
#   'rel_url': '/movie/4-minute-mile',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'4 Minute Mile'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/around-the-block',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Around the Block'},
#  {'metascore_w': 18,
#   'rel_url': '/movie/behaving-badly',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Behaving Badly'},
#  {'metascore_w': 77,
#   'rel_url': '/movie/calvary',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Calvary'},
#  {'metascore_w': 50,
#   'rel_url': '/movie/child-of-god',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Child of God'},
#  {'metascore_w': 64,
#   'rel_url': '/movie/finding-fela!',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Finding Fela!'},
#  {'metascore_w': 66,
#   'rel_url': '/movie/moebius',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Moebius'},
#  {'metascore_w': 32,
#   'rel_url': '/movie/rabindranath-tagore-the-poet-of-eternity',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Rabindranath Tagore: The Poet of Eternity'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/raw-cut',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Raw Cut'},
#  {'metascore_w': 75,
#   'rel_url': '/movie/rich-hill',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Rich Hill'},
#  {'metascore_w': 64,
#   'rel_url': '/movie/the-almost-man',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Almost Man'},
#  {'metascore_w': 80,
#   'rel_url': '/movie/the-strange-little-cat',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Strange Little Cat'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/what-about-me',
#   'release_date': datetime.datetime(2014, 8, 1, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'What About Me'},
#  {'metascore_w': 50,
#   'rel_url': '/movie/war-story',
#   'release_date': datetime.datetime(2014, 7, 30, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'War Story'},
#  {'metascore_w': 34,
#   'rel_url': '/movie/beneath-2014',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Beneath'},
#  {'metascore_w': 69,
#   'rel_url': '/movie/cannibal',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Cannibal'},
#  {'metascore_w': 31,
#   'rel_url': '/movie/come-back-to-me',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Come Back to Me'},
#  {'metascore_w': 70,
#   'rel_url': '/movie/happy-christmas',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Happy Christmas'},
#  {'metascore_w': 22,
#   'rel_url': '/movie/ironclad-battle-for-blood',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Ironclad: Battle for Blood'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/kick',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Kick'},
#  {'metascore_w': 56,
#   'rel_url': '/movie/the-fluffy-movie',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Fluffy Movie'},
#  {'metascore_w': 72,
#   'rel_url': '/movie/the-kill-team',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'The Kill Team'},
#  {'metascore_w': 35,
#   'rel_url': '/movie/very-good-girls',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Very Good Girls'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/without-shepherds',
#   'release_date': datetime.datetime(2014, 7, 25, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Without Shepherds'},
#  {'metascore_w': 65,
#   'rel_url': '/movie/a-letter-to-momo',
#   'release_date': datetime.datetime(2014, 7, 23, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'A Letter to Momo'},
#  {'metascore_w': 67,
#   'rel_url': '/movie/a-master-builder',
#   'release_date': datetime.datetime(2014, 7, 23, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'A Master Builder'},
#  {'metascore_w': 51,
#   'rel_url': '/movie/a-five-star-life',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'A Five Star Life'},
#  {'metascore_w': 67,
#   'rel_url': '/movie/alive-inside',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Alive Inside'},
#  {'metascore_w': 8,
#   'rel_url': '/movie/among-ravens',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Among Ravens'},
#  {'metascore_w': 71,
#   'rel_url': '/movie/double-play-james-benning-and-richard-linklater',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Double Play: James Benning and Richard Linklater'},
#  {'metascore_w': 46,
#   'rel_url': '/movie/fanny',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Fanny'},
#  {'metascore_w': 56,
#   'rel_url': '/movie/i-origins',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'I Origins'},
#  {'metascore_w': u'tbd',
#   'rel_url': '/movie/k-missing-kings',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'K Missing Kings'},
#  {'metascore_w': 54,
#   'rel_url': '/movie/mood-indigo',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Mood Indigo'},
#  {'metascore_w': 40,
#   'rel_url': '/movie/video-games-the-movie',
#   'release_date': datetime.datetime(2014, 7, 18, 0, 0),
#   'release_type': u'Limited releases now in theaters',
#   'title': u'Video Games: The Movie'}]

# %% [markdown]
# ##Alternatively,
# You can check out the above functions, run them one-by-one, and see how the guts work.
#
# Go back and forth between this notebook and the page we're parsing (http://www.metacritic.com/browse/movies/release-date/theaters/date) to see what it's doing.
#
# **Protip**: when you're scraping, it's a good idea to open your target page in an "incognito" window, so that your sessions and plugins and ad blockers and whatnot do not cause you to see things differently than the html you're parsing from your response object.

# %% [markdown]
# I've included some exploration in the scratchpad cell below to get you started.

# %%
from pprint import pprint

#Playing around with the functions

modules = get_modules(soup)
#print type(modules)
#print modules.keys()

label,wide_release_module = modules.items()[0]

#print label
#print wide_release_module

#for item in wide_release_module: print type(item),item.name

#print wide_release_module[0]

movie = parse_movie_li(wide_release_module[0])
pprint(movie)
# Out:
# {'metascore_w': 59,
#  'rel_url': '/movie/dolphin-tale-2',
#  'release_date': datetime.datetime(2014, 9, 12, 0, 0),
#  'title': u'Dolphin Tale 2'}

# %% [markdown]
# ## Why Requests is awesome (again):
# **.history and redirects**
#
# During the workshop I mentioned briefly that the `Response` object saves a history that shows you any redirects that your request went through to get your eventual response, and that it helped me debug an item in the metacritic scraper.
#
# Below is the trickster item that was giving me trouble. See if you can figure out how to get the redirect url from the r object. The [docs pages](http://docs.python-requests.org/en/v0.10.6/api/) for requests should be helpful.

# %%
url = 'http://www.metacritic.com/movie/frank-millers-sin-city-a-dame-to-kill-for/critic-reviews?num_items=30&critic_reviews_page=0'
#url = 'http://www.metacritic.com/movie/frank-millers-sin-city-a-dame-to-kill-for'

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
r = requests.get(url,headers=headers)

#print r.ok
#print r.history
